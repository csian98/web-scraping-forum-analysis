# %%
from c_main import main

# %%
main()
# Out:
# Fetching posts with embeddings from Snowflake...
# Fetched 62 posts with embeddings from Snowflake
#
# Sample posts from Cluster 0:
# - One line of code 102 blocked threads Wrote up the full investigation with thread dumps and JDK sourc...
# - Pentagon threatens to cut off Anthropic in AI safeguards dispute...
#
# Sample posts from Cluster 1:
# - What differentiates a high impact analytics function from one that just produces dashboards Im curio...
# - Best technique for training models on a sample of data Due to memory limits on my work computer Im u...
